# %%
import pandas as pd
import numpy as np
import analysis
studentInfo = pd.read_csv("student_info.csv")
grades = pd.read_csv("grades.csv")
grades
# Out:
#       student_id                                       file_name  grade  \
# 0              1        202511293_1학년_컴퓨터과학과_주서연_정시_censored.pdf      1
# 1              1        202511293_1학년_컴퓨터과학과_주서연_정시_censored.pdf      2
# 2              1        202511293_1학년_컴퓨터과학과_주서연_정시_censored.pdf      1
# 3              1        202511293_1학년_컴퓨터과학과_주서연_정시_censored.pdf      1
# 4              1        202511293_1학년_컴퓨터과학과_주서연_정시_censored.pdf      1
# ...          ...                                             ...    ...
# 3537          69  202511291_1_자유전공학부(인문사회계열)_조은진_정시_censored.pdf      3
# 3538          69  202511291_1_자유전공학부(인문사회계열)_조은진_정시_censored.pdf      3
# 3539          69  202511291_1_자유전공학부(인문사회계열)_조은진_정시_censored.pdf      3
# 3540          69  202511291_1_자유전공학부(인문사회계열)_조은진_정시_censored.pdf      3
# 3541          69  202511291_1_자유전공학부(인문사회계열)_조은진_정시_censored.pdf      3
#
#       semester subject rank_grade
# 0            1      국어          2
# ...

# %%
# Out:
# array([], dtype=object)

# %%
for i in range(1,4):
    for k in range(1,3):
        print(f"Course {i}, Semester {k}: Mean Rank = {np.mean(analysis.getSusiRank(i,k,grades, studentInfo))}")
# Out:
# Course 1, Semester 1: Mean Rank = 3.050909090909091
# Course 1, Semester 2: Mean Rank = 3.1484375
# Course 2, Semester 1: Mean Rank = 3.2329749103942653
# Course 2, Semester 2: Mean Rank = 3.2625482625482625
# Course 3, Semester 1: Mean Rank = 2.1474358974358974
# Course 3, Semester 2: Mean Rank = 2.328358208955224
